# %%
# importing several libraries
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np
import string
import nltk
import nltk.corpus
import sklearn
import string

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\priya\anaconda3\lib\site-packages (from wordcloud) (1.21.0)
# Requirement already satisfied: pillow in c:\users\priya\anaconda3\lib\site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: matplotlib in c:\users\priya\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\priya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.2-cp39-cp39-win_amd64.whl (153 kB)
#    ---------------------------------------- 153.3/153.3 kB 9.5 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\priya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\priya\anaconda3\lib\site-packages)

# %%
from matplotlib import rcParams
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords 
from nltk import NaiveBayesClassifier
from nltk.corpus import wordnet 
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk import pos_tag
from wordcloud import WordCloud
from sklearn.ensemble import RandomForestClassifier 
from nltk.classify.scikitlearn import SklearnClassifier

# %%
# Specify the path to the CSV file
data_path = r'C:\Users\priya\Documents\Web Mining\Womens Clothing E-Commerce Reviews.csv'

# Read the CSV file into a DataFrame
df=pd.read_csv(data_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
# display column names
df.columns
# Out:
# Index(['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name'],
#       dtype='object')

# %%
# check the shape of the dataset, rows and columns
df.shape
# Out:
# (23486, 11)

# %%
# Count the number of unique values in each column
df.nunique()
# Out:
# Unnamed: 0                 23486
# Clothing ID                 1206
# Age                           77
# Title                      13993
# Review Text                22634
# Rating                         5
# Recommended IND                2
# Positive Feedback Count       82
# Division Name                  3
# Department Name                6
# Class Name                    20
# dtype: int64

# %%
# Count the number of nulls in each column
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
# remove any row that contains at least one NaN value
df.dropna(inplace=True)

# %%
# reset the index after dropping some rows 
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           2         1077   60  Some major design flaws
# 1           3         1049   50         My favorite buy!
# 2           4          847   47         Flattering shirt
# 3           5         1080   49  Not for the very petite
# 4           6          858   39     Cagrcoal shimmer fun
#
#                                          Review Text  Rating  Recommended IND  \
# 0  I had such high hopes for this dress and reall...       3                0
# 1  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 2  This shirt is very flattering to all due to th...       5                1
# 3  I love tracy reese dresses, but this one is no...       2                0
# 4  I aded this in my basket at hte last mintue to...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0         General         Dresses    Dresses
# 1                        0  General Petite         Bottoms      Pants
# 2                        6         General            Tops    Blouses
# 3                        4         General         Dresses    Dresses
# 4                        1  General Petite            Tops      Knits

# %%
# Check for the missing values after droping the null values 
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Clothing ID                0
# Age                        0
# Title                      0
# Review Text                0
# Rating                     0
# Recommended IND            0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# dtype: int64

# %%
# drop unnecessary culomns 
df.drop(["Unnamed: 0", "Title", 'Clothing ID'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age                                        Review Text  Rating  \
# 0   60  I had such high hopes for this dress and reall...       3
# 1   50  I love, love, love this jumpsuit. it's fun, fl...       5
# 2   47  This shirt is very flattering to all due to th...       5
# 3   49  I love tracy reese dresses, but this one is no...       2
# 4   39  I aded this in my basket at hte last mintue to...       5
#
#    Recommended IND  Positive Feedback Count   Division Name Department Name  \
# 0                0                        0         General         Dresses
# 1                1                        0  General Petite         Bottoms
# 2                1                        6         General            Tops
# 3                0                        4         General         Dresses
# 4                1                        1  General Petite            Tops
#
#   Class Name
# 0    Dresses
# 1      Pants
# 2    Blouses
# 3    Dresses
# 4      Knits

# %%
# to remove spaces in columns and replace them with underscore 
df.columns= df.columns.str.replace(" ", "_")

# %%
# Create reviews Tuples to store the words alongwith  the categories 
reviews = []
# go through Recommended IND column and get the category and the index 
for (index , category) in enumerate(df.Recommended_IND):
    reviews.append((df.Review_Text[index],category)) # Store the review for spacific index with catogory inside texts array
# Print first 4
reviews[0:4]
# Out:
# [('I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c',
#   0),
#  ("I love, love, love this jumpsuit. it's fun, flirty, and fabulous! every time i wear it, i get nothing but great compliments!",
#   1),
#  ('This shirt is very flattering to all due to the adjustable front tie. it is the perfect length to wear with leggings and it is sleeveless so it pairs well with any cardigan. love this shirt!!!',
#   1),
#  ('I love tracy reese dresses, but this one is not for the very petite. i am just under 5 feet tall and usually wear a 0p in this brand. this dress was very pretty out of the package but its a lot of dress. the skirt is long and very full so it overwhelmed my small frame. not a stranger to alterations, shortening and narrowing the skirt would take away from the embellishment of the garment. i love the color and the idea of the style but it just did not work on me. i returned this dress.',
#   0)]

# %%
# create lemmatizer 
lemmatizer = WordNetLemmatizer()

# %%
# download necessary resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Create a list of stopwords 
# Get English stopwords
stops = set(stopwords.words('english'))

# Get a set of specific punctuation marks
punctuations = set(string.punctuation)
#print(punctuations)
# Combine stopwords and punctuation sets
stops.update(punctuations)

# %%
# total stopwords
len(stops)
# Out:
# 211

# %%
# function to get the simpler version of pos tag  to use it in lemmitazation 
def get_simple_pos(tag):
    tag_start = tag[0].upper()
    if tag_start == 'N':
        return wordnet.NOUN
    elif tag_start == 'V':
        return wordnet.VERB
    elif tag_start == 'R':
        return wordnet.ADV
    else:
        return wordnet.NOUN  # default case

# %%
# function to return Lemmatized words and cleaned from stop words
def clean_review(words):
    words_tokens = word_tokenize(words)
    
    output_words = [
        lemmatizer.lemmatize(word.lower(), pos=get_simple_pos(tag))
        for word, tag in pos_tag(words_tokens)
        if word.lower() not in stops and any(c.isalnum() for c in word)
    ]
    
    return output_words

# %%
cleaned_words = clean_review("My cats are running away from my arms")
print(cleaned_words)
# Out:
# ['cat', 'run', 'away', 'arm']

# %%
cleaned_reviews= [(clean_review(text),category )for text,category  in reviews]

# %%
# copy clean version into excel spreadsheet to be used for tableau purposes
# Create a DataFrame from the list of tuples
df = pd.DataFrame(cleaned_reviews, columns=['Cleaned_Text', 'Category'])

# Save the DataFrame to an Excel file
df.to_excel('cleaned_data.xlsx', index=False)

# %%
#check first 5 reviews 
cleaned_reviews[0:5]
# Out:
# [(['high',
#    'hope',
#    'dress',
#    'really',
#    'want',
#    'work',
#    'initially',
#    'order',
#    'petite',
#    'small',
#    'usual',
#    'size',
#    'find',
#    'outrageously',
#    'small',
#    'small',
#    'fact',
#    'could',
#    'zip',
#    'reorder',
#    'petite',
#    'medium',
#    'ok.',
#    'overall',
#    'top',
#    'half',
#    'comfortable',
#    'fit',
#    'nicely',
#    'bottom',
#    'half',
#    'tight',
#    'layer',
#    'several',
#    'somewhat',
#    'cheap',
#    'net',
#    'layer',
#    'imo',
#    'major',
#    'design',
#    'flaw',
#    'net',
#    'layer',
#    'sewn',
#    'directly',
#    'zipper',
#    'c'],
#   0),
#  (['love',
#    'love',
#    'love',
#    'jumpsuit',
#    "'s",
#    'fun',
#    'flirty',
#    'fabulous',
#    'every',
#    'time',
#    'wear',
#    'get',
#    'nothing',
#    'great',
#    'compliment'],
#   1),
#  (['shirt',
#    'flattering',
#    'due',
#    'adjustable',
#    'front',
#    'tie',
#    'perfect',
#    'length',
#    'wear',
#    'legging',
#    'sleeveless',
#    'pair',
#    'well',
#    'cardigan',
#    'love',
#    'shirt'],
#   1),
#  (['love',
#    'tracy',
#    'reese',
#    'dress',
#    'one',
#    'petite',
#    '5',
#    'foot',
#    'tall',
#    'usually',
#    'wear',
#    '0p',
#    'brand',
#    'dress',
#    'pretty',
#    'package',
#    'lot',
#    'dress',
#    'skirt',
#    'long',
#    'full',
#    'overwhelm',
#    'small',
#    'frame',
#    'stranger',
#    'alteration',
#    'shorten',
#    'narrow',
#    'skirt',
#    'would',
#    'take',
#    'away',
#    'embellishment',
#    'garment',
#    'love',
#    'color',
#    'idea',
#    'style',
#    'work',
#    'return',
#    'dress'],
#   0),
#  (['aded',
#    'basket',
#    'hte',
#    'last',
#    'mintue',
#    'see',
#    'would',
#    'look',
#    'like',
#    'person',
#    'store',
#    'pick',
#    'go',
#    'teh',
#    'darkler',
#    'color',
#    'pale',
#    'hte',
#    'color',
#    'really',
#    'gorgeous',
#    'turn',
#    'mathced',
#    'everythiing',
#    'try',
#    'prefectly',
#    'little',
#    'baggy',
#    'hte',
#    'x',
#    'hte',
#    'msallet',
#    'size',
#    'bummer',
#    'petite',
#    'decide',
#    'jkeep',
#    'though',
#    'say',
#    'matvehd',
#    'everything',
#    'ejans',
#    'pant',
#    '3',
#    'skirt',
#    'waas',
#    'try',
#    'kept',
#    'oops'],
#   1)]

# %%
#.75% traning = 14746 and 25% testing = 19662-14746 =4916 
#traning_words=cleaned_reviews[0:14746]
#testing_words=cleaned_reviews[14746:]

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\priya\anaconda3\lib\site-packages (1.0.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.14.6 in c:\users\priya\anaconda3\lib\site-packages (from scikit-learn) (1.21.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\priya\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\priya\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\priya\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Collecting numpy>=1.14.6 (from scikit-learn)
#   Downloading numpy-1.26.2-cp39-cp39-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 61.2/61.2 kB 3.2 MB/s eta 0:00:00
# Downloading numpy-1.26.2-cp39-cp39-win_amd64.whl (15.8 MB)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\priya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\priya\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\priya\\anaconda3\\Lib\\site-packages\\numpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Consider using the `--user` option or check the permissions.
#    ---------------------------------------- 15.8/15.8 MB 34.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.0
#     Uninstalling numpy-1.21.0:
#       Successfully uninstalled numpy-1.21.0
#   Rolling back uninstall of numpy
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy-1.21.0.dist-info\
#    from C:\Users\priya\anaconda3\Lib\site-packages\~umpy-1.21.0.dist-info
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\.libs\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\~libs
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__config__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__config__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__init__.cython-30.pxd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__init__.cython-30.pxd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__init__.pxd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__init__.pxd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__init__.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__init__.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\__config__.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\__config__.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\_distributor_init.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\_distributor_init.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\_globals.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\_globals.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\_pytesttester.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\_pytesttester.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\conftest.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\conftest.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\ctypeslib.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\ctypeslib.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\matlib.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\matlib.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\__pycache__\version.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\__pycache__\version.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\_distributor_init.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\_distributor_init.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\_globals.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\_globals.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\_pytesttester.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\_pytesttester.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\compat\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\~ompat
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\conftest.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\conftest.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__init__.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__init__.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_add_newdocs.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_add_newdocs.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_add_newdocs_scalars.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_add_newdocs_scalars.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_asarray.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_asarray.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_dtype.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_dtype.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_dtype_ctypes.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_dtype_ctypes.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_exceptions.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_exceptions.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_internal.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_internal.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_methods.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_methods.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_string_helpers.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_string_helpers.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_type_aliases.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_type_aliases.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\_ufunc_config.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\_ufunc_config.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\arrayprint.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\arrayprint.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\cversions.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\cversions.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\defchararray.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\defchararray.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\einsumfunc.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\einsumfunc.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\fromnumeric.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\fromnumeric.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\function_base.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\function_base.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\getlimits.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\getlimits.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\memmap.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\memmap.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\multiarray.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\multiarray.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\numeric.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\numeric.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\numerictypes.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\numerictypes.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\overrides.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\overrides.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\records.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\records.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\shape_base.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\shape_base.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\umath.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\umath.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\__pycache__\umath_tests.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\__pycache__\umath_tests.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_add_newdocs.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_add_newdocs.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_add_newdocs_scalars.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_add_newdocs_scalars.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_asarray.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_asarray.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_asarray.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_asarray.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_dtype.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_dtype.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_dtype_ctypes.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_dtype_ctypes.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_exceptions.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_exceptions.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_internal.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_internal.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_internal.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_internal.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_methods.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_methods.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_multiarray_tests.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_multiarray_tests.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_multiarray_umath.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_multiarray_umath.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_operand_flag_tests.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_operand_flag_tests.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_rational_tests.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_rational_tests.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_simd.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_simd.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_string_helpers.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_string_helpers.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_struct_ufunc_tests.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_struct_ufunc_tests.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_type_aliases.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_type_aliases.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_type_aliases.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_type_aliases.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_ufunc_config.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_ufunc_config.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_ufunc_config.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\_umath_tests.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\_umath_tests.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\arrayprint.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\arrayprint.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\arrayprint.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\arrayprint.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\cversions.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\cversions.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\defchararray.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\defchararray.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\einsumfunc.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\einsumfunc.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\einsumfunc.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\einsumfunc.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\fromnumeric.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\fromnumeric.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\fromnumeric.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\fromnumeric.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\function_base.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\function_base.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\function_base.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\function_base.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\getlimits.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\getlimits.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\__multiarray_api.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\__multiarray_api.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\__ufunc_api.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\__ufunc_api.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\_neighborhood_iterator_imp.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\_neighborhood_iterator_imp.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\_numpyconfig.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\_numpyconfig.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\arrayobject.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\arrayobject.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\arrayscalars.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\arrayscalars.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\halffloat.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\halffloat.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\ndarrayobject.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\ndarrayobject.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\ndarraytypes.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\ndarraytypes.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\noprefix.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\noprefix.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_1_7_deprecated_api.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_3kcompat.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_3kcompat.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_common.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_common.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_cpu.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_cpu.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_endian.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_endian.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_interrupt.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_interrupt.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_math.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_math.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_no_deprecated_api.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_no_deprecated_api.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_os.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\npy_os.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\numpyconfig.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\numpyconfig.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\old_defines.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\old_defines.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\random\bitgen.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\random\bitgen.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\random\distributions.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\random\distributions.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\ufuncobject.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\ufuncobject.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\include\numpy\utils.h
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\include\numpy\utils.h
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\lib\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\core\~ib
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\memmap.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\memmap.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\multiarray.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\multiarray.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\numeric.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\numeric.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\numeric.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\numeric.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\numerictypes.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\numerictypes.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\numerictypes.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\numerictypes.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\overrides.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\overrides.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\records.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\records.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\shape_base.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\shape_base.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\shape_base.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\shape_base.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\_locales.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\_locales.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test__exceptions.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test__exceptions.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_abc.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_abc.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_api.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_api.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_argparse.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_argparse.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_array_coercion.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_array_coercion.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_arraymethod.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_arraymethod.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_arrayprint.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_arrayprint.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_casting_unittests.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_casting_unittests.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_conversion_utils.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_conversion_utils.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_cpu_dispatcher.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_cpu_dispatcher.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_cpu_features.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_cpu_features.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_cython.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_cython.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_datetime.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_datetime.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_defchararray.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_defchararray.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_deprecations.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_deprecations.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_dtype.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_dtype.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_einsum.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_einsum.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_errstate.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_errstate.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_extint128.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_extint128.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_function_base.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_function_base.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_getlimits.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_getlimits.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_half.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_half.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_indexerrors.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_indexerrors.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_indexing.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_indexing.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_item_selection.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_item_selection.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_longdouble.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_longdouble.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_machar.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_machar.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_mem_overlap.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_mem_overlap.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_memmap.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_memmap.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_multiarray.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_multiarray.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_nditer.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_nditer.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_numeric.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_numeric.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_numerictypes.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_numerictypes.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_overrides.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_overrides.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_print.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_print.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_protocols.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_protocols.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_records.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_records.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_regression.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_regression.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_scalar_ctors.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_scalar_ctors.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_scalar_methods.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_scalar_methods.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_scalarbuffer.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_scalarbuffer.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_scalarinherit.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_scalarinherit.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_scalarmath.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_scalarmath.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_scalarprint.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_scalarprint.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_shape_base.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_shape_base.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_simd.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_simd.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_simd_module.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_simd_module.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_ufunc.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_ufunc.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_umath.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_umath.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_umath_accuracy.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_umath_accuracy.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_umath_complex.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_umath_complex.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\test_unicode.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\__pycache__\test_unicode.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\_locales.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\_locales.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\data\astype_copy.pkl
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\data\astype_copy.pkl
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\data\recarray_from_file.fits
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\data\recarray_from_file.fits
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\data\umath-validation-set-cos.csv
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\data\umath-validation-set-cos.csv
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\data\umath-validation-set-exp.csv
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\data\umath-validation-set-exp.csv
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\data\umath-validation-set-log.csv
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\data\umath-validation-set-log.csv
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\data\umath-validation-set-readme.txt
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\data\umath-validation-set-readme.txt
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\data\umath-validation-set-sin.csv
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\data\umath-validation-set-sin.csv
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test__exceptions.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test__exceptions.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_abc.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_abc.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_api.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_api.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_argparse.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_argparse.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_array_coercion.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_array_coercion.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_arraymethod.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_arraymethod.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_arrayprint.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_arrayprint.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_casting_unittests.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_casting_unittests.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_conversion_utils.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_conversion_utils.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_cpu_dispatcher.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_cpu_dispatcher.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_cpu_features.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_cpu_features.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_cython.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_cython.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_datetime.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_datetime.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_defchararray.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_defchararray.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_deprecations.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_deprecations.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_dtype.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_dtype.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_einsum.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_einsum.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_errstate.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_errstate.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_extint128.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_extint128.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_function_base.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_function_base.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_getlimits.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_getlimits.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_half.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_half.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_indexerrors.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_indexerrors.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_indexing.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_indexing.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_item_selection.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_item_selection.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_longdouble.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_longdouble.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_machar.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_machar.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_mem_overlap.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_mem_overlap.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_memmap.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_memmap.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_multiarray.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_multiarray.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_nditer.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_nditer.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_numeric.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_numeric.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_numerictypes.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_numerictypes.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_overrides.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_overrides.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_print.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_print.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_protocols.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_protocols.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_records.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_records.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_regression.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_regression.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_scalar_ctors.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_scalar_ctors.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_scalar_methods.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_scalar_methods.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_scalarbuffer.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_scalarbuffer.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_scalarinherit.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_scalarinherit.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_scalarmath.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_scalarmath.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_scalarprint.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_scalarprint.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_shape_base.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_shape_base.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_simd.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_simd.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_simd_module.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_simd_module.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_ufunc.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_ufunc.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_umath.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_umath.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_umath_accuracy.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_umath_accuracy.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_umath_complex.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\core\tests\test_umath_complex.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\core\tests\test_unicode.py
# ...
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\__pycache__\test_polynomial.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\__pycache__\test_polyutils.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\__pycache__\test_polyutils.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\__pycache__\test_printing.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\__pycache__\test_printing.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_chebyshev.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_chebyshev.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_classes.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_classes.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_hermite.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_hermite.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_hermite_e.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_hermite_e.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_laguerre.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_laguerre.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_legendre.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_legendre.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_polynomial.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_polynomial.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_polyutils.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_polyutils.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\polynomial\tests\test_printing.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\polynomial\tests\test_printing.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\py.typed
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\py.typed
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\__init__.pxd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\__init__.pxd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\__init__.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\__init__.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\__pycache__\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\random\~_pycache__
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_bounded_integers.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_bounded_integers.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_bounded_integers.pxd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_bounded_integers.pxd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_common.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_common.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_common.pxd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_common.pxd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_examples\cffi\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\random\_examples\~ffi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_examples\cython\extending.pyx
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_examples\cython\extending.pyx
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_examples\cython\extending_distributions.pyx
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_examples\cython\extending_distributions.pyx
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_examples\numba\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\random\_examples\~umba
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_generator.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_generator.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_generator.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_generator.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_mt19937.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_mt19937.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_mt19937.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_mt19937.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_pcg64.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_pcg64.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_pcg64.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_pcg64.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_philox.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_philox.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_philox.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_philox.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_pickle.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_pickle.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_sfc64.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_sfc64.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\_sfc64.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\_sfc64.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\bit_generator.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\bit_generator.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\bit_generator.pxd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\bit_generator.pxd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\bit_generator.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\bit_generator.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\c_distributions.pxd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\c_distributions.pxd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\lib\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\random\~ib
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\mtrand.cp39-win_amd64.pyd
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\mtrand.cp39-win_amd64.pyd
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\mtrand.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\random\mtrand.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\random\tests\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\random\~ests
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\__init__.pyi
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\__init__.pyi
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\__pycache__\print_coercion_tables.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\__pycache__\print_coercion_tables.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\__pycache__\setup.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\__pycache__\setup.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\_private\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\_private\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\_private\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\_private\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\_private\__pycache__\utils.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\_private\__pycache__\utils.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\_private\utils.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\_private\utils.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\print_coercion_tables.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\print_coercion_tables.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\setup.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\testing\setup.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\testing\tests\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\testing\~ests
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_ctypeslib.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__pycache__\test_ctypeslib.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_matlib.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__pycache__\test_matlib.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_numpy_version.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__pycache__\test_numpy_version.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_public_api.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__pycache__\test_public_api.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_reloading.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__pycache__\test_reloading.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_scripts.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__pycache__\test_scripts.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_warnings.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\__pycache__\test_warnings.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\test_ctypeslib.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\test_ctypeslib.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\test_matlib.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\test_matlib.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\test_numpy_version.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\test_numpy_version.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\test_public_api.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\test_public_api.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\test_reloading.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\test_reloading.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\test_scripts.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\test_scripts.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\tests\test_warnings.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\tests\test_warnings.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\__pycache__\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\typing\~_pycache__
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\mypy_plugin.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\mypy_plugin.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\setup.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\setup.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\tests\__init__.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\tests\__init__.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\tests\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\tests\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\tests\__pycache__\test_isfile.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\tests\__pycache__\test_isfile.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\tests\__pycache__\test_typing.cpython-39.pyc
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\tests\__pycache__\test_typing.cpython-39.pyc
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\tests\data\mypy.ini
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\tests\data\mypy.ini
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\tests\data\pass\
#    from C:\Users\priya\anaconda3\Lib\site-packages\numpy\typing\tests\data\~ass
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\tests\test_isfile.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\tests\test_isfile.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\typing\tests\test_typing.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\typing\tests\test_typing.py
#   Moving to c:\users\priya\anaconda3\lib\site-packages\numpy\version.py
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-jwbe8d_p\version.py
#   Moving to c:\users\priya\anaconda3\scripts\f2py.exe
#    from C:\Users\priya\AppData\Local\Temp\pip-uninstall-yxgbh7an\f2py.exe

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets (e.g., 80% training, 20% testing)
training_words, testing_words = train_test_split(cleaned_reviews, test_size=0.2, random_state=42)

# %%
print(f"Training Data = {len(training_words)}")
print(f"Testing Data = {len(testing_words)}")
# Out:
# Training Data = 15729
# Testing Data = 3933

# %%
# array contaning all words 
words_list=[]
for word in training_words:
        words_list+=word[0] # 0 index to get only the words

# %%
# Total words in traning data 
len(words_list)
# Out:
# 490039

# %%
#frequency distribution for all words 
freq= nltk.FreqDist(words_list)
# The .most_common() method lists the words which occur most frequently in the data along with the frequency
common=freq.most_common()
# features are an array of only the top words in word list without The number of words 
features= [i[0]for i in common]

# %%
print(len(common))
print(len(features))
# Out:
# 13780
# 13780

# %%
# Most common 5 words 
common[0:5]
# Out:
# [('dress', 8570),
#  ('fit', 7719),
#  ('size', 7402),
#  ('love', 7092),
#  ('wear', 7010)]

# %%
# List of 5 features 
features[0:5]
# Out:
# ['dress', 'fit', 'size', 'love', 'wear']

# %%
# Visualizing the highest repeating words (features)

# wordcload is techniqe use to show which words are the most frequent 
wordCloud = WordCloud(background_color="white", max_words =3000).generate(str(features))

rcParams["figure.figsize"]= 10,20
plt.imshow(wordCloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# function to return a set of the features with true or false 
def get_dict_for_feature(words):
  current_features={}
  words_set= set(words)
  for word in features:
    current_features[word] = word in words_set  # if word comes in words set it will return True otherwise False 
  return current_features

# %%
featuers_dic= get_dict_for_feature(training_words[0][0])

# %%
# Dictionary containing all words with True classification if the word is exist in each review otherwise false  
featuers_dic
# Out:
# {'dress': False,
#  'fit': False,
#  'size': False,
#  'love': False,
#  'wear': False,
#  'look': True,
#  "n't": False,
#  'top': False,
#  "'s": False,
#  'like': False,
#  'color': False,
#  "'m": False,
#  'great': True,
#  'would': False,
#  '5': False,
#  'order': False,
#  'get': False,
#  'fabric': False,
#  'small': False,
#  'make': False,
#  'go': False,
#  'buy': True,
#  'really': False,
#  'well': False,
#  'perfect': False,
#  'one': True,
#  'little': False,
#  'try': False,
#  'think': False,
#  'soft': False,
#  'back': False,
#  'nice': False,
#  'run': False,
#  'comfortable': True,
#  'cute': False,
#  'work': False,
#  'bit': False,
#  'material': False,
#  'large': False,
#  'beautiful': False,
#  'shirt': False,
#  'length': False,
#  'sweater': True,
#  'much': False,
#  'also': False,
#  'jean': False,
#  'petite': False,
#  'long': False,
#  'could': False,
#  'short': False,
#  'waist': False,
#  'purchase': False,
#  'skirt': False,
#  'medium': False,
#  'even': False,
#  'quality': False,
#  'retailer': False,
#  'pretty': False,
#  'feel': False,
#  'want': False,
#  'x': False,
#  'store': False,
#  'usually': False,
#  'find': False,
#  'pant': False,
#  'good': False,
#  'sleeve': False,
#  'way': False,
#  'cut': False,
#  'see': False,
#  'style': False,
#  'flattering': False,
#  'big': False,
#  'still': False,
#  'flatter': False,
#  'black': False,
#  'return': False,
#  'right': False,
#  'true': False,
#  'design': False,
#  'super': False,
#  'online': False,
#  'say': False,
#  '4': False,
#  'keep': False,
#  'need': False,
#  'arm': False,
#  'however': False,
#  '2': False,
#  'picture': False,
#  'enough': False,
#  'white': False,
#  'perfectly': False,
#  'tight': False,
#  'fall': False,
#  'model': False,
#  'summer': False,
#  'pair': False,
#  'time': False,
#  'detail': False,
#  'sale': False,
#  'bottom': False,
#  'front': False,
#  'shoulder': False,
#  'lb': False,
#  'though': False,
#  'definitely': False,
#  'give': False,
#  'price': False,
#  'blue': False,
#  'show': False,
#  'person': False,
#  'jacket': False,
#  'side': False,
#  'take': False,
#  'come': False,
#  'first': False,
#  '6': False,
#  'piece': False,
#  'review': False,
#  'body': False,
#  'shape': False,
#  'regular': False,
#  'loose': False,
#  'button': False,
#  'around': False,
#  "'ve": False,
#  'lot': False,
#  'photo': False,
#  'day': False,
#  'many': False,
#  'pattern': False,
#  'chest': False,
#  'seem': False,
#  'saw': False,
#  'recommend': False,
#  'bust': False,
#  'wash': False,
#  'light': False,
#  'compliment': False,
#  'hip': False,
#  'high': False,
#  'lovely': False,
#  'print': False,
#  'thin': False,
#  'blouse': False,
#  'without': False,
#  'gorgeous': False,
#  'receive': False,
#  'casual': False,
#  'bra': False,
#  'line': False,
#  'wish': False,
#  'sure': False,
#  'ca': False,
#  '8': False,
#  'reviewer': False,
#  'stretch': False,
#  'thing': False,
#  'hit': False,
#  'usual': False,
#  'since': False,
#  'normally': False,
#  'overall': False,
#  'quite': False,
#  'longer': False,
#  'weight': False,
#  '3': False,
#  'different': False,
#  'expect': False,
#  'comfy': False,
#  'nicely': False,
#  'slightly': False,
#  'may': False,
#  'know': False,
#  'felt': False,
#  'absolutely': False,
#  'might': False,
#  'legging': False,
#  'underneath': False,
#  'add': True,
#  'green': False,
#  'pocket': False,
#  'area': False,
#  'two': False,
#  'another': True,
#  'tee': False,
#  'unique': False,
#  'red': False,
#  'tank': False,
#  'probably': False,
#  'actually': False,
#  'lace': False,
#  'easy': False,
#  'extra': False,
#  "'re": False,
#  'knee': False,
#  'wait': False,
#  'fun': False,
#  'end': False,
#  'layer': False,
#  'warm': False,
#  'decide': False,
#  'almost': False,
#  'happy': False,
#  "'d": False,
#  'boxy': False,
#  'wide': False,
#  'something': False,
#  'year': False,
#  'put': False,
#  'fine': False,
#  'drape': False,
#  'hang': False,
#  'better': False,
#  'sheer': False,
#  'boot': False,
#  'flowy': False,
#  'figure': False,
#  'neck': False,
#  'smaller': False,
#  'worth': False,
#  'leg': False,
#  'hem': False,
#  'tall': False,
#  'unfortunately': False,
#  'yet': False,
#  'glad': False,
#  'part': False,
#  'shorter': False,
#  "'ll": False,
#  'skinny': False,
#  'problem': False,
#  'reference': False,
#  'use': False,
#  'low': False,
#  'denim': False,
#  'every': False,
#  'maybe': False,
#  'always': False,
#  'pull': False,
#  'full': False,
#  'everything': False,
#  'adorable': False,
#  'neckline': False,
#  'larger': False,
#  'issue': False,
#  'huge': False,
#  'tie': False,
#  'thick': False,
#  'favorite': False,
#  'versatile': False,
#  'slip': False,
#  'coat': False,
#  'tt': False,
#  'especially': False,
#  'best': False,
#  'room': False,
#  'navy': False,
#  'inch': False,
#  'snug': False,
#  'easily': False,
#  'knit': False,
#  'pink': False,
#  'heavy': False,
#  'winter': False,
#  'lightweight': False,
#  'normal': False,
#  'belt': False,
#  '7': False,
#  'sell': False,
#  'flow': False,
#  'tunic': False,
#  'feminine': False,
#  'dark': False,
#  'cotton': False,
#  'grey': False,
#  'cardigan': False,
#  'hole': False,
#  'xl': False,
#  'item': False,
#  'flat': False,
#  'type': False,
#  'kind': False,
#  'typically': False,
#  'spring': False,
#  'cami': False,
#  'beautifully': False,
#  '10': False,
#  'strap': False,
#  'embroidery': False,
#  'frame': False,
#  'although': False,
#  'suit': False,
#  'torso': False,
#  'extremely': False,
#  'hop': False,
#  'able': False,
#  'brand': False,
#  'never': False,
#  '1': False,
#  'cover': False,
#  'open': False,
#  '0': False,
#  'someone': False,
#  'either': False,
#  'highly': False,
#  'zipper': False,
#  'arrive': False,
#  'today': False,
#  'place': False,
#  'heel': False,
#  'anything': False,
#  'curvy': False,
#  'read': False,
#  'flare': False,
#  'plan': False,
#  'agree': False,
#  'cool': False,
#  'bad': False,
#  'season': False,
#  'already': False,
#  'xx': False,
#  'seam': False,
#  'swing': False,
#  'stretchy': False,
#  'hold': False,
#  'weather': False,
#  'new': False,
#  'dry': False,
#  'last': False,
#  'disappointed': False,
#  'lining': False,
#  'due': False,
#  'fell': False,
#  'surprise': False,
#  'skin': False,
#  'exactly': False,
#  'unflattering': False,
#  'hard': False,
#  'sizing': False,
#  'cheap': False,
#  'touch': False,
#  'l': False,
#  'vest': False,
#  'ankle': False,
#  'local': False,
#  'otherwise': False,
#  'cozy': False,
#  'appear': False,
#  'wardrobe': False,
#  'mention': False,
#  'away': False,
#  'others': False,
#  'help': False,
#  'gray': False,
#  'orange': False,
#  'plus': False,
#  'rather': False,
#  'hot': False,
#  'tad': False,
#  'across': False,
#  'mean': False,
#  'classic': False,
#  'vibrant': False,
#  'sadly': False,
#  'night': False,
#  'slim': False,
#  'least': False,
#  'consider': False,
#  'base': False,
#  'several': False,
#  '9': False,
#  'hope': False,
#  'eye': False,
#  'nothing': False,
#  'send': False,
#  'lay': False,
#  'version': False,
#  'stylish': False,
#  'sometimes': False,
#  'stripe': False,
#  'wonderful': False,
#  'exchange': False,
#  'bright': False,
#  'ever': False,
#  't-shirt': False,
#  'far': False,
#  'baggy': False,
#  'roomy': False,
#  'fitting': False,
#  'must': False,
#  'simple': False,
#  'prefer': False,
#  'pilcro': False,
#  'hide': False,
#  'fitted': False,
#  'itchy': False,
#  'leave': False,
#  'disappoint': False,
#  'pound': False,
#  'wrinkle': False,
#  'month': False,
#  'straight': False,
#  'busty': False,
#  '12': False,
#  'yellow': False,
#  'texture': True,
#  'girl': False,
#  'thigh': False,
#  'delicate': False,
#  'wo': False,
#  'instead': False,
#  '115': False,
#  'tights': False,
#  'tuck': False,
#  'tiny': False,
#  'notice': False,
#  'oversized': False,
#  'booty': False,
#  'mine': False,
#  'worry': False,
#  'immediately': False,
#  'outfit': False,
#  'jumpsuit': False,
#  'woman': False,
#  'elastic': False,
#  'completely': False,
#  'amazing': False,
#  'available': False,
#  'sandal': False,
#  'close': False,
#  'cold': False,
#  'wedding': False,
#  'reason': False,
#  'bigger': False,
#  'pay': False,
#  'lower': False,
#  'amaze': False,
#  'shrink': False,
#  'staple': False,
#  'special': False,
#  'curve': False,
#  'sit': False,
#  'collar': False,
#  'previous': False,
#  'totally': False,
#  'excited': False,
#  'similar': False,
#  'wool': False,
#  'star': False,
#  'throw': False,
#  'armhole': False,
#  'fact': False,
#  'incredibly': False,
#  'note': False,
#  'depend': False,
#  'point': False,
#  'zip': False,
#  'stay': False,
#  'ivory': False,
#  'spot': False,
#  'weird': False,
#  'rise': False,
#  'tell': False,
#  'build': False,
#  'else': False,
#  'higher': False,
#  'people': False,
#  'basic': False,
#  'complaint': False,
#  'finally': False,
#  'crop': False,
#  'stiff': False,
#  'clothes': False,
#  'slimming': False,
#  'sexy': False,
#  'broad': False,
#  'mind': False,
#  'slit': False,
#  'often': False,
#  'wrong': False,
#  'inside': False,
#  'neutral': False,
#  'rich': False,
#  'athletic': False,
#  'week': False,
#  'hourglass': False,
#  'amount': False,
#  'second': False,
#  'substantial': False,
#  'odd': False,
#  'snag': False,
#  'awesome': False,
#  'pleat': False,
#  'home': False,
#  'deep': False,
#  'mail': False,
#  'ruffle': False,
#  'couple': False,
#  'dressy': False,
#  'hand': False,
#  'elegant': False,
#  'closet': False,
#  'brown': False,
#  'silk': False,
#  'half': False,
#  'bulky': False,
#  'next': False,
#  '34b': False,
#  'option': False,
#  '26': False,
#  'roll': False,
#  'appropriate': False,
#  'upper': False,
#  'imagine': False,
#  'peplum': False,
#  'stick': False,
#  'start': False,
#  'live': False,
#  'subtle': False,
#  'product': False,
#  'thread': False,
#  'forward': False,
#  'match': False,
#  'blazer': False,
#  'cream': False,
#  'clothing': False,
#  'waisted': False,
#  'linen': False,
#  'stand': False,
#  'addition': False,
#  'walk': False,
#  'thicker': False,
#  '120': False,
#  'lose': False,
#  'justice': False,
#  'bodice': False,
#  '34c': False,
#  'soon': False,
#  'cup': False,
#  'romper': False,
#  'somewhat': False,
#  'weekend': False,
#  'idea': False,
#  'motif': False,
#  'pick': False,
#  'except': False,
#  'transition': False,
#  'fan': False,
#  'see-through': False,
#  'perhaps': False,
#  'interesting': True,
#  'sort': False,
#  'nude': False,
#  'everywhere': False,
#  'floral': False,
#  'case': False,
#  'maeve': False,
#  'baby': False,
#  'anyway': False,
#  'looser': False,
#  'tailor': False,
#  'stun': False,
#  '135': False,
#  '30': False,
#  'tag': False,
#  'maternity': False,
#  'ok': False,
#  'sad': False,
#  'flower': False,
#  'party': False,
#  '27': False,
#  'fairly': False,
#  'band': False,
#  'along': False,
#  'darker': False,
#  'excite': False,
#  'sweatshirt': False,
#  'real': False,
#  '28': False,
#  'move': False,
#  'purple': False,
#  'classy': False,
#  'hug': False,
#  'lady': False,
#  'form': False,
#  'le': False,
#  'slight': False,
#  'deal': False,
#  '125': False,
#  'taller': False,
#  'pic': False,
#  'opinion': False,
#  'narrow': False,
#  'together': False,
#  'ton': False,
#  'heavier': False,
#  'office': False,
#  'become': False,
#  'pleased': False,
#  'coverage': False,
#  'cuff': False,
#  'three': False,
#  'awkward': False,
#  'tend': False,
#  'yes': False,
#  'gold': False,
#  'please': False,
#  'chic': False,
#  'v': False,
#  'occasion': False,
#  'waistband': False,
#  'middle': False,
#  'anyone': False,
#  'husband': False,
#  'necklace': False,
#  '140': False,
#  'structure': False,
#  'barely': False,
#  'truly': False,
#  'past': False,
#  'p': False,
#  'butt': False,
#  'typical': False,
#  'holiday': False,
#  'shade': False,
#  'fabulous': False,
#  'tent': False,
#  'strange': False,
#  'state': False,
#  'whole': False,
#  'believe': False,
#  'gap': False,
#  '100': False,
#  'choose': False,
#  'cropped': False,
#  'turn': False,
#  'bring': False,
#  'portion': False,
#  'fantastic': False,
#  'leather': False,
#  'dinner': False,
#  'guess': False,
#  'catch': False,
#  'let': False,
#  'swim': False,
#  'foot': False,
#  'draw': False,
#  'worn': False,
#  '130': False,
#  'unless': False,
#  'pop': False,
#  'tummy': False,
#  'edge': False,
#  'scratchy': False,
#  'mid': False,
#  'comfort': False,
#  'happen': False,
#  'event': False,
#  "5'10": False,
#  'do': False,
#  'wider': False,
#  'realize': False,
#  'generally': False,
#  'clean': False,
#  'u': False,
#  'frumpy': False,
#  'belly': False,
#  'beach': False,
#  'rest': False,
#  'tone': False,
#  'comment': False,
#  'thought': False,
#  'lighter': False,
#  'change': False,
#  'snap': False,
#  'bag': False,
#  'old': False,
#  'everyone': False,
#  'miss': False,
#  'require': False,
#  'airy': False,
#  'create': False,
#  'simply': False,
#  'ago': False,
#  'pictured': False,
#  'wow': False,
#  'solid': False,
#  'chance': False,
#  'height': False,
#  'adore': False,
#  '25': False,
#  'plenty': False,
#  'hour': False,
#  'sew': False,
#  'suggest': False,
#  'allow': False,
#  'suppose': False,
#  'money': False,
#  'flaw': False,
#  'cooler': False,
#  'grab': False,
#  'daughter': False,
#  'head': False,
#  'expensive': False,
#  'glove': False,
#  'plaid': False,
#  'clingy': False,
#  'b': False,
#  'pregnant': False,
#  'description': False,
#  'care': False,
#  'difficult': False,
#  'despite': False,
#  'fix': False,
#  '34d': False,
#  'excellent': False,
#  'wore': False,
#  'camisole': False,
#  'keeper': False,
#  'dot': False,
#  'stock': False,
#  'concern': False,
#  'house': False,
#  'maxi': False,
#  'silky': False,
#  'prettier': False,
#  '4.': False,
#  'shoe': False,
#  'minute': False,
#  'pass': False,
#  '34': False,
#  'slender': False,
#  'interest': True,
#  'etc': False,
#  'wedge': False,
#  'call': False,
#  'silhouette': False,
#  'natural': False,
#  'compare': False,
#  'chested': False,
#  '39': False,
#  'bother': False,
#  'ag': False,
#  'website': False,
#  'coral': False,
#  'stitching': False,
#  'feature': False,
#  'swingy': False,
#  'shapeless': False,
#  'polyester': False,
#  'pale': False,
#  'combination': False,
#  'stomach': False,
#  'styling': False,
#  'bought': False,
#  'twice': False,
#  'wrap': False,
#  'oh': False,
#  'offer': False,
#  'c': False,
#  'afraid': False,
#  'plain': False,
#  'uncomfortable': False,
#  'bunch': False,
#  'remind': False,
#  'yesterday': False,
#  'construction': False,
#  'evening': False,
#  'check': False,
#  'originally': False,
#  'carry': False,
#  'trim': False,
#  'stitch': False,
#  'pencil': False,
#  'okay': False,
#  '6.': False,
#  'stop': False,
#  'garment': False,
#  'bum': False,
#  'movement': False,
#  'recently': False,
#  'friend': False,
#  'a-line': False,
#  'pricey': False,
#  'average': False,
#  '36c': False,
#  'poor': False,
#  'less': False,
#  'th': False,
#  'bell': False,
#  'life': False,
#  'section': False,
#  'package': False,
#  'v-neck': False,
#  'sweet': False,
#  'machine': False,
#  'fold': False,
#  'w': False,
#  'hanger': False,
#  'cling': False,
#  'throughout': False,
#  '20': False,
#  'designer': False,
#  'billowy': False,
#  'scarf': False,
#  'lounge': False,
#  'weigh': False,
#  'tighter': False,
#  'contrast': False,
#  'cause': False,
#  'stunning': False,
#  'detailing': False,
#  'appreciate': False,
#  'effect': False,
#  '2.': False,
#  'near': False,
#  'water': False,
#  'trip': False,
#  'sack': False,
#  'difference': False,
#  'nicer': False,
#  'literally': False,
#  'turtleneck': False,
#  'relaxed': False,
#  'likely': False,
#  'support': False,
#  'weave': False,
#  '29': False,
#  'velvet': False,
#  'choice': False,
#  'travel': False,
#  'write': False,
#  'wonder': False,
#  'proportion': False,
#  'opening': False,
#  'iron': False,
#  'overly': False,
#  'combo': False,
#  'poncho': False,
#  'beauty': False,
#  'romantic': False,
#  'thrill': False,
#  'later': False,
#  'unlike': False,
#  'panel': False,
#  'everyday': False,
#  'ask': False,
#  'surprised': False,
#  'beading': False,
#  'shot': False,
#  'warmer': False,
#  '0p': False,
#  'crazy': False,
#  'multiple': False,
#  'pleasantly': False,
#  'dream': False,
#  'cuter': False,
#  '145': False,
#  'round': False,
#  '36d': False,
#  'spend': False,
#  'reveal': False,
#  'beige': False,
#  'negative': False,
#  'strapless': False,
#  'sloppy': False,
#  'adjustable': False,
#  'pin': False,
#  'describe': False,
#  'surprisingly': False,
#  'hesitant': False,
#  'well-made': False,
#  'mom': False,
#  'waistline': False,
#  'xsp': False,
#  'feeling': False,
#  'set': False,
#  'gal': False,
#  'fence': False,
#  'accentuate': False,
#  'attractive': False,
#  'whether': False,
#  'm/l': False,
#  'wonderfully': False,
#  'exception': False,
#  '110': False,
#  'trouser': False,
#  'mix': False,
#  'boyfriend': False,
#  'unusual': False,
#  'outside': False,
#  'hook': False,
#  'thanks': False,
#  'breast': False,
#  '3/4': False,
#  'comfortably': False,
#  'blend': False,
#  'date': False,
#  'mostly': False,
#  'rayon': False,
#  'careful': False,
#  'upon': False,
#  'provide': False,
#  'double': False,
#  '40': False,
#  'alter': False,
#  'search': False,
#  'particularly': False,
#  'alone': False,
#  'turquoise': False,
#  'swimsuit': False,
#  'quickly': False,
#  'moss': False,
#  'initially': False,
#  'im': False,
#  'brighter': False,
#  'cinch': False,
#  'statement': False,
#  'rib': False,
#  'vibe': False,
#  'calf': False,
#  'entire': False,
#  'bow': False,
#  'tan': False,
#  'teal': False,
#  'center': False,
#  'early': False,
#  'awful': False,
#  'hate': False,
#  'course': False,
#  'disappointing': False,
#  'armpit': False,
#  'boob': False,
#  'hung': False,
#  '36': False,
#  'trouble': False,
#  'terrible': False,
#  'christmas': False,
#  'wine': False,
#  'errand': False,
#  'dd': False,
#  'muscular': False,
#  'pajama': False,
#  'flimsy': False,
#  'attention': False,
#  '14': False,
#  'overwhelm': False,
#  'whim': False,
#  'olive': False,
#  'con': False,
#  'sleeveless': True,
#  'chino': False,
#  'adjust': False,
#  'pear': False,
#  'xxsp': False,
#  'closure': False,
#  '34dd': False,
#  '36dd': False,
#  'hopefully': False,
#  'thank': False,
#  'rack': False,
#  'rip': False,
#  'sleep': False,
#  'post': False,
#  'vintage': False,
#  'kimono': False,
#  'gift': False,
#  'skim': False,
#  'sewn': False,
#  'go-to': False,
#  'vacation': False,
#  'follow': False,
#  'include': False,
#  'trend': False,
#  'avoid': False,
#  'cleavage': False,
#  'currently': False,
#  'bead': False,
#  'moment': False,
#  'cord': False,
#  'winner': False,
#  'honestly': False,
#  'hte': False,
#  'cloth': False,
#  'standard': False,
#  's.': False,
#  'jersey': False,
#  'wrist': False,
#  'lavender': False,
#  'shop': False,
#  'discount': False,
#  'bump': False,
#  'peach': False,
#  'amp': False,
#  'mother': False,
#  'flair': False,
#  'bulk': False,
#  'tts': False,
#  ...}

# %%
# create dic for each review wich has feature with value and the category
training_words= [( get_dict_for_feature(words),category ) for words , category in training_words]
testing_words = [( get_dict_for_feature(words),category ) for words , category in testing_words]

# %%
training_words[1]
# Out:
# ({'dress': False,
#   'fit': True,
#   'size': True,
#   'love': False,
#   'wear': True,
#   'look': False,
#   "n't": False,
#   'top': True,
#   "'s": False,
#   'like': False,
#   'color': True,
#   "'m": False,
#   'great': True,
#   'would': False,
#   '5': False,
#   'order': False,
#   'get': False,
#   'fabric': False,
#   'small': False,
#   'make': True,
#   'go': False,
#   'buy': False,
#   'really': False,
#   'well': False,
#   'perfect': False,
#   'one': False,
#   'little': True,
#   'try': False,
#   'think': False,
#   'soft': False,
#   'back': False,
#   'nice': False,
#   'run': True,
#   'comfortable': False,
#   'cute': False,
#   'work': False,
#   'bit': False,
#   'material': False,
#   'large': False,
#   'beautiful': True,
#   'shirt': False,
#   'length': False,
#   'sweater': False,
#   'much': False,
#   'also': False,
#   'jean': False,
#   'petite': False,
#   'long': True,
#   'could': False,
#   'short': False,
#   'waist': False,
#   'purchase': True,
#   'skirt': False,
#   'medium': False,
#   'even': True,
#   'quality': False,
#   'retailer': False,
#   'pretty': False,
#   'feel': False,
#   'want': False,
#   'x': False,
#   'store': False,
#   'usually': False,
#   'find': False,
#   'pant': False,
#   'good': False,
#   'sleeve': True,
#   'way': False,
#   'cut': False,
#   'see': False,
#   'style': False,
#   'flattering': False,
#   'big': False,
#   'still': False,
#   'flatter': False,
#   'black': False,
#   'return': False,
#   'right': False,
#   'true': True,
#   'design': False,
#   'super': False,
#   'online': False,
#   'say': False,
#   '4': False,
#   'keep': False,
#   'need': False,
#   'arm': True,
#   'however': False,
#   '2': False,
#   'picture': False,
#   'enough': False,
#   'white': False,
#   'perfectly': False,
#   'tight': False,
#   'fall': True,
#   'model': False,
#   'summer': False,
#   'pair': False,
#   'time': False,
#   'detail': False,
#   'sale': False,
#   'bottom': False,
#   'front': False,
#   'shoulder': False,
#   'lb': False,
#   'though': False,
#   'definitely': True,
#   'give': True,
#   'price': False,
#   'blue': False,
#   'show': False,
#   'person': False,
#   'jacket': False,
#   'side': True,
#   'take': False,
#   'come': False,
#   'first': False,
#   '6': False,
#   'piece': False,
#   'review': False,
#   'body': False,
#   'shape': True,
#   'regular': False,
#   'loose': False,
#   'button': False,
#   'around': False,
#   "'ve": False,
#   'lot': False,
#   'photo': False,
#   'day': False,
#   'many': False,
#   'pattern': False,
#   'chest': True,
#   'seem': False,
#   'saw': True,
#   'recommend': False,
#   'bust': False,
#   'wash': False,
#   'light': False,
#   'compliment': False,
#   'hip': False,
#   'high': False,
#   'lovely': False,
#   'print': False,
#   'thin': False,
#   'blouse': False,
#   'without': False,
#   'gorgeous': False,
#   'receive': False,
#   'casual': False,
#   'bra': False,
#   'line': False,
#   'wish': False,
#   'sure': False,
#   'ca': False,
#   '8': False,
#   'reviewer': False,
#   'stretch': False,
#   'thing': False,
#   'hit': False,
#   'usual': False,
#   'since': False,
#   'normally': False,
#   'overall': False,
#   'quite': False,
#   'longer': False,
#   'weight': False,
#   '3': False,
#   'different': False,
#   'expect': False,
#   'comfy': False,
#   'nicely': False,
#   'slightly': False,
#   'may': False,
#   'know': False,
#   'felt': False,
#   'absolutely': False,
#   'might': False,
#   'legging': False,
#   'underneath': False,
#   'add': True,
#   'green': False,
#   'pocket': False,
#   'area': False,
#   'two': False,
#   'another': False,
#   'tee': False,
#   'unique': False,
#   'red': False,
#   'tank': False,
#   'probably': False,
#   'actually': False,
#   'lace': False,
#   'easy': True,
#   'extra': False,
#   "'re": False,
#   'knee': False,
#   'wait': False,
#   'fun': False,
#   'end': False,
#   'layer': False,
#   'warm': False,
#   'decide': False,
#   'almost': False,
#   'happy': False,
#   "'d": False,
#   'boxy': False,
#   'wide': False,
#   'something': False,
#   'year': False,
#   'put': False,
#   'fine': False,
#   'drape': False,
#   'hang': False,
#   'better': False,
#   'sheer': False,
#   'boot': False,
#   'flowy': False,
#   'figure': False,
#   'neck': False,
#   'smaller': False,
#   'worth': False,
#   'leg': False,
#   'hem': False,
#   'tall': False,
#   'unfortunately': False,
#   'yet': False,
#   'glad': False,
#   'part': False,
#   'shorter': False,
#   "'ll": False,
#   'skinny': False,
#   'problem': False,
#   'reference': False,
#   'use': False,
#   'low': False,
#   'denim': False,
#   'every': True,
#   'maybe': False,
#   'always': False,
#   'pull': False,
#   'full': False,
#   'everything': False,
#   'adorable': False,
#   'neckline': False,
#   'larger': False,
#   'issue': False,
#   'huge': False,
#   'tie': False,
#   'thick': False,
#   'favorite': False,
#   'versatile': False,
#   'slip': False,
#   'coat': False,
#   'tt': False,
#   'especially': False,
#   'best': False,
#   'room': False,
#   'navy': False,
#   'inch': False,
#   'snug': False,
#   'easily': False,
#   'knit': True,
#   'pink': False,
#   'heavy': False,
#   'winter': False,
#   'lightweight': False,
#   'normal': False,
#   'belt': False,
#   '7': False,
#   'sell': False,
#   'flow': False,
#   'tunic': False,
#   'feminine': False,
#   'dark': False,
#   'cotton': False,
#   'grey': False,
#   'cardigan': False,
#   'hole': False,
#   'xl': False,
#   'item': False,
#   'flat': False,
#   'type': False,
#   'kind': False,
#   'typically': False,
#   'spring': False,
#   'cami': False,
#   'beautifully': False,
#   '10': False,
#   'strap': False,
#   'embroidery': False,
#   'frame': False,
#   'although': False,
#   'suit': False,
#   'torso': False,
#   'extremely': False,
#   'hop': False,
#   'able': False,
#   'brand': False,
#   'never': False,
#   '1': False,
#   'cover': False,
#   'open': False,
#   '0': False,
#   'someone': False,
#   'either': False,
#   'highly': False,
#   'zipper': False,
#   'arrive': False,
#   'today': False,
#   'place': False,
#   'heel': False,
#   'anything': False,
#   'curvy': False,
#   'read': False,
#   'flare': False,
#   'plan': False,
#   'agree': False,
#   'cool': False,
#   'bad': False,
#   'season': False,
#   'already': False,
#   'xx': False,
#   'seam': False,
#   'swing': True,
#   'stretchy': False,
#   'hold': False,
#   'weather': False,
#   'new': False,
#   'dry': False,
#   'last': False,
#   'disappointed': False,
#   'lining': False,
#   'due': False,
#   'fell': False,
#   'surprise': False,
#   'skin': False,
#   'exactly': False,
#   'unflattering': False,
#   'hard': False,
#   'sizing': False,
#   'cheap': False,
#   'touch': False,
#   'l': False,
#   'vest': False,
#   'ankle': False,
#   'local': False,
#   'otherwise': False,
#   'cozy': False,
#   'appear': False,
#   'wardrobe': False,
#   'mention': False,
#   'away': False,
#   'others': False,
#   'help': False,
#   'gray': False,
#   'orange': False,
#   'plus': False,
#   'rather': False,
#   'hot': False,
#   'tad': False,
#   'across': False,
#   'mean': False,
#   'classic': False,
#   'vibrant': False,
#   'sadly': False,
#   'night': False,
#   'slim': False,
#   'least': False,
#   'consider': False,
#   'base': False,
#   'several': False,
#   '9': False,
#   'hope': False,
#   'eye': False,
#   'nothing': False,
#   'send': False,
#   'lay': False,
#   'version': False,
#   'stylish': False,
#   'sometimes': False,
#   'stripe': False,
#   'wonderful': False,
#   'exchange': False,
#   'bright': False,
#   'ever': False,
#   't-shirt': False,
#   'far': False,
#   'baggy': False,
#   'roomy': False,
#   'fitting': False,
#   'must': False,
#   'simple': False,
#   'prefer': False,
#   'pilcro': False,
#   'hide': False,
#   'fitted': False,
#   'itchy': False,
#   'leave': False,
#   'disappoint': False,
#   'pound': False,
#   'wrinkle': False,
#   'month': False,
#   'straight': False,
#   'busty': False,
#   '12': False,
#   'yellow': False,
#   'texture': False,
#   'girl': False,
#   'thigh': False,
#   'delicate': False,
#   'wo': False,
#   'instead': False,
#   '115': False,
#   'tights': False,
#   'tuck': False,
#   'tiny': False,
#   'notice': False,
#   'oversized': False,
#   'booty': False,
#   'mine': False,
#   'worry': False,
#   'immediately': False,
#   'outfit': False,
#   'jumpsuit': False,
#   'woman': False,
#   'elastic': False,
#   'completely': False,
#   'amazing': False,
#   'available': False,
#   'sandal': False,
#   'close': False,
#   'cold': False,
#   'wedding': False,
#   'reason': False,
#   'bigger': True,
#   'pay': False,
#   'lower': False,
#   'amaze': False,
#   'shrink': False,
#   'staple': False,
#   'special': False,
#   'curve': False,
#   'sit': False,
#   'collar': False,
#   'previous': False,
#   'totally': False,
#   'excited': False,
#   'similar': True,
#   'wool': False,
#   'star': False,
#   'throw': False,
#   'armhole': False,
#   'fact': False,
#   'incredibly': False,
#   'note': False,
#   'depend': False,
#   'point': False,
#   'zip': False,
#   'stay': False,
#   'ivory': False,
#   'spot': False,
#   'weird': False,
#   'rise': False,
#   'tell': False,
#   'build': False,
#   'else': False,
#   'higher': False,
#   'people': False,
#   'basic': False,
#   'complaint': False,
#   'finally': False,
#   'crop': False,
#   'stiff': False,
#   'clothes': False,
#   'slimming': False,
#   'sexy': False,
#   'broad': False,
#   'mind': False,
#   'slit': False,
#   'often': False,
#   'wrong': False,
#   'inside': False,
#   'neutral': False,
#   'rich': False,
#   'athletic': False,
#   'week': False,
#   'hourglass': False,
#   'amount': False,
#   'second': False,
#   'substantial': False,
#   'odd': False,
#   'snag': False,
#   'awesome': False,
#   'pleat': False,
#   'home': False,
#   'deep': False,
#   'mail': False,
#   'ruffle': False,
#   'couple': False,
#   'dressy': False,
#   'hand': False,
#   'elegant': False,
#   'closet': False,
#   'brown': False,
#   'silk': False,
#   'half': False,
#   'bulky': False,
#   'next': False,
#   '34b': False,
#   'option': False,
#   '26': False,
#   'roll': False,
#   'appropriate': False,
#   'upper': False,
#   'imagine': False,
#   'peplum': False,
#   'stick': False,
#   'start': False,
#   'live': False,
#   'subtle': False,
#   'product': False,
#   'thread': False,
#   'forward': False,
#   'match': False,
#   'blazer': False,
#   'cream': False,
#   'clothing': False,
#   'waisted': False,
#   'linen': True,
#   'stand': False,
#   'addition': False,
#   'walk': False,
#   'thicker': False,
#   '120': False,
#   'lose': False,
#   'justice': False,
#   'bodice': False,
#   '34c': False,
#   'soon': False,
#   'cup': False,
#   'romper': False,
#   'somewhat': False,
#   'weekend': False,
#   'idea': False,
#   'motif': False,
#   'pick': False,
#   'except': False,
#   'transition': False,
#   'fan': False,
#   'see-through': False,
#   'perhaps': False,
#   'interesting': False,
#   'sort': False,
#   'nude': False,
#   'everywhere': False,
#   'floral': False,
#   'case': False,
#   'maeve': False,
#   'baby': False,
#   'anyway': False,
#   'looser': False,
#   'tailor': False,
#   'stun': False,
#   '135': False,
#   '30': False,
#   'tag': False,
#   'maternity': False,
#   'ok': False,
#   'sad': False,
#   'flower': False,
#   'party': False,
#   '27': False,
#   'fairly': False,
#   'band': False,
#   'along': False,
#   'darker': False,
#   'excite': False,
#   'sweatshirt': False,
#   'real': False,
#   '28': False,
#   'move': False,
#   'purple': False,
#   'classy': False,
#   'hug': False,
#   'lady': False,
#   'form': False,
#   'le': False,
#   'slight': False,
#   'deal': False,
#   '125': False,
#   'taller': False,
#   'pic': False,
#   'opinion': False,
#   'narrow': False,
#   'together': False,
#   'ton': False,
#   'heavier': False,
#   'office': False,
#   'become': False,
#   'pleased': False,
#   'coverage': False,
#   'cuff': False,
#   'three': False,
#   'awkward': False,
#   'tend': False,
#   'yes': False,
#   'gold': False,
#   'please': False,
#   'chic': False,
#   'v': False,
#   'occasion': False,
#   'waistband': False,
#   'middle': False,
#   'anyone': False,
#   'husband': False,
#   'necklace': False,
#   '140': False,
#   'structure': False,
#   'barely': False,
#   'truly': False,
#   'past': False,
#   'p': False,
#   'butt': False,
#   'typical': False,
#   'holiday': False,
#   'shade': False,
#   'fabulous': False,
#   'tent': False,
#   'strange': False,
#   'state': False,
#   'whole': False,
#   'believe': False,
#   'gap': False,
#   '100': False,
#   'choose': False,
#   'cropped': False,
#   'turn': False,
#   'bring': False,
#   'portion': False,
#   'fantastic': False,
#   'leather': False,
#   'dinner': False,
#   'guess': False,
#   'catch': False,
#   'let': False,
#   'swim': False,
#   'foot': False,
#   'draw': False,
#   'worn': False,
#   '130': False,
#   'unless': False,
#   'pop': False,
#   'tummy': False,
#   'edge': False,
#   'scratchy': False,
#   'mid': False,
#   'comfort': False,
#   'happen': False,
#   'event': False,
#   "5'10": False,
#   'do': False,
#   'wider': False,
#   'realize': False,
#   'generally': False,
#   'clean': False,
#   'u': False,
#   'frumpy': False,
#   'belly': False,
#   'beach': False,
#   'rest': False,
#   'tone': False,
#   'comment': False,
#   'thought': False,
#   'lighter': False,
#   'change': False,
#   'snap': False,
#   'bag': False,
#   'old': False,
#   'everyone': False,
#   'miss': False,
#   'require': False,
#   'airy': False,
#   'create': False,
#   'simply': False,
#   'ago': False,
#   'pictured': False,
#   'wow': False,
#   'solid': False,
#   'chance': False,
#   'height': False,
#   'adore': False,
#   '25': False,
#   'plenty': False,
#   'hour': False,
#   'sew': False,
#   'suggest': False,
#   'allow': False,
#   'suppose': False,
#   'money': False,
#   'flaw': False,
#   'cooler': False,
#   'grab': False,
#   'daughter': False,
#   'head': False,
#   'expensive': False,
#   'glove': False,
#   'plaid': False,
#   'clingy': False,
#   'b': False,
#   'pregnant': False,
#   'description': False,
#   'care': False,
#   'difficult': False,
#   'despite': False,
#   'fix': False,
#   '34d': False,
#   'excellent': False,
#   'wore': False,
#   'camisole': False,
#   'keeper': False,
#   'dot': False,
#   'stock': False,
#   'concern': False,
#   'house': False,
#   'maxi': False,
#   'silky': False,
#   'prettier': False,
#   '4.': False,
#   'shoe': False,
#   'minute': False,
#   'pass': False,
#   '34': False,
#   'slender': False,
#   'interest': False,
#   'etc': False,
#   'wedge': False,
#   'call': False,
#   'silhouette': False,
#   'natural': False,
#   'compare': False,
#   'chested': False,
#   '39': False,
#   'bother': False,
#   'ag': False,
#   'website': False,
#   'coral': False,
#   'stitching': False,
#   'feature': False,
#   'swingy': False,
#   'shapeless': False,
#   'polyester': False,
#   'pale': False,
#   'combination': False,
#   'stomach': False,
#   'styling': False,
#   'bought': False,
#   'twice': False,
#   'wrap': False,
#   'oh': False,
#   'offer': False,
#   'c': False,
#   'afraid': False,
#   'plain': False,
#   'uncomfortable': False,
#   'bunch': False,
#   'remind': False,
#   'yesterday': False,
#   'construction': False,
#   'evening': False,
#   'check': False,
#   'originally': False,
#   'carry': False,
#   'trim': False,
#   'stitch': False,
#   'pencil': False,
#   'okay': False,
#   '6.': False,
#   'stop': False,
#   'garment': False,
#   'bum': False,
#   'movement': False,
#   'recently': False,
#   'friend': False,
#   'a-line': False,
#   'pricey': False,
#   'average': False,
#   '36c': False,
#   'poor': False,
#   'less': False,
#   'th': False,
#   'bell': False,
#   'life': False,
#   'section': False,
#   'package': False,
#   'v-neck': False,
#   'sweet': False,
#   'machine': False,
#   'fold': False,
#   'w': False,
#   'hanger': False,
#   'cling': False,
#   'throughout': False,
#   '20': False,
#   'designer': False,
#   'billowy': False,
#   'scarf': False,
#   'lounge': False,
#   'weigh': False,
#   'tighter': False,
#   'contrast': False,
#   'cause': False,
#   'stunning': False,
#   'detailing': False,
#   'appreciate': False,
#   'effect': False,
#   '2.': False,
#   'near': False,
#   'water': False,
#   'trip': False,
#   'sack': False,
#   'difference': False,
#   'nicer': False,
#   'literally': False,
#   'turtleneck': False,
#   'relaxed': False,
#   'likely': False,
#   'support': False,
#   'weave': False,
#   '29': False,
#   'velvet': False,
#   'choice': False,
#   'travel': False,
#   'write': False,
#   'wonder': False,
#   'proportion': False,
#   'opening': False,
#   'iron': False,
#   'overly': False,
#   'combo': False,
#   'poncho': False,
#   'beauty': False,
#   'romantic': False,
#   'thrill': False,
#   'later': False,
#   'unlike': False,
#   'panel': False,
#   'everyday': False,
#   'ask': False,
#   'surprised': False,
#   'beading': False,
#   'shot': False,
#   'warmer': False,
#   '0p': False,
#   'crazy': False,
#   'multiple': False,
#   'pleasantly': False,
#   'dream': False,
#   'cuter': False,
#   '145': False,
#   'round': False,
#   '36d': False,
#   'spend': False,
#   'reveal': False,
#   'beige': False,
#   'negative': False,
#   'strapless': False,
#   'sloppy': False,
#   'adjustable': False,
#   'pin': False,
#   'describe': False,
#   'surprisingly': False,
#   'hesitant': False,
#   'well-made': False,
#   'mom': False,
#   'waistline': False,
#   'xsp': False,
#   'feeling': False,
#   'set': False,
#   'gal': False,
#   'fence': False,
#   'accentuate': False,
#   'attractive': False,
#   'whether': False,
#   'm/l': False,
#   'wonderfully': False,
#   'exception': False,
#   '110': False,
#   'trouser': False,
#   'mix': False,
#   'boyfriend': False,
#   'unusual': False,
#   'outside': False,
#   'hook': False,
#   'thanks': False,
#   'breast': False,
#   '3/4': False,
#   'comfortably': False,
#   'blend': False,
#   'date': False,
#   'mostly': False,
#   'rayon': False,
#   'careful': False,
#   'upon': False,
#   'provide': False,
#   'double': False,
#   '40': False,
#   'alter': False,
#   'search': False,
#   'particularly': False,
#   'alone': False,
#   'turquoise': False,
#   'swimsuit': False,
#   'quickly': False,
#   'moss': False,
#   'initially': False,
#   'im': False,
#   'brighter': False,
#   'cinch': False,
#   'statement': False,
#   'rib': False,
#   'vibe': False,
#   'calf': False,
#   'entire': False,
#   'bow': False,
#   'tan': False,
#   'teal': False,
#   'center': True,
#   'early': False,
#   'awful': False,
#   'hate': False,
#   'course': False,
#   'disappointing': False,
#   'armpit': False,
#   'boob': False,
#   'hung': False,
#   '36': False,
#   'trouble': False,
#   'terrible': False,
#   'christmas': False,
#   'wine': False,
#   'errand': False,
#   'dd': False,
#   'muscular': False,
#   'pajama': False,
#   'flimsy': False,
#   'attention': False,
#   '14': False,
#   'overwhelm': False,
#   'whim': False,
#   'olive': False,
#   'con': False,
#   'sleeveless': False,
#   'chino': False,
#   'adjust': False,
#   'pear': False,
#   'xxsp': False,
#   'closure': False,
#   '34dd': False,
#   '36dd': False,
#   'hopefully': False,
#   'thank': False,
#   'rack': False,
#   'rip': False,
#   'sleep': False,
#   'post': False,
#   'vintage': False,
#   'kimono': False,
#   'gift': False,
#   'skim': False,
#   'sewn': False,
#   'go-to': False,
#   'vacation': False,
#   'follow': False,
#   'include': False,
#   'trend': False,
#   'avoid': False,
#   'cleavage': False,
#   'currently': False,
#   'bead': False,
#   'moment': False,
#   'cord': False,
#   'winner': False,
#   'honestly': False,
#   'hte': False,
#   'cloth': False,
#   'standard': False,
#   's.': False,
#   'jersey': False,
#   'wrist': False,
#   'lavender': False,
#   'shop': False,
#   'discount': False,
#   'bump': False,
#   'peach': False,
#   'amp': False,
#   'mother': False,
#   'flair': False,
#   'bulk': False,
#   'tts': False,
#   ...},
#  1)

# %%
# to the classifier we need to use NaiveBayesClassifier and pass the training words to it 
NB_classifier= NaiveBayesClassifier.train(training_words)
print("classifier accuracy percent:",(nltk.classify.accuracy(NB_classifier, training_words))*100)
# Out:
# classifier accuracy percent: 91.57606968020853

# %%
review_1 = "Super fast and responsive with any issues. Different style print option was great! Easy to order and a pleasure to have done business with. Looking forward to ordering more items! Thank you"
review_2= "I am thrilled with the quality & fit of the t-shirts& they were very nicely packaged too. I will definitely be re-ordering from you in the future. - Kristina - Spain"
review_3="Missing refunds. Returned parcel and got a date that I would get the refund by, five days after this date no refund. Contacted customer support and they advised I have to wait another 14 days. The service was very unhelpful and rude at times."
reviews = [review_1,review_2,review_3]


def test_custom_review(reviews_list, classifier):
    
    for idx,review in enumerate(reviews_list) : 
        custom_tokens = clean_review(review)
        print(f"The clean review is : "  , str(custom_tokens).replace('[','').replace(']',''))
        classifiers=classifier.classify(dict([token, True] for token in custom_tokens))
        if (classifiers == 1):
            pred = "Positive"
        else:
            pred = "Negative"
        print(f"Review number {idx +1 }  seems to be {pred} \n")

# %%
test_custom_review(reviews,NB_classifier)
# Out:
# The clean review is :  'super', 'fast', 'responsive', 'issue', 'different', 'style', 'print', 'option', 'great', 'easy', 'order', 'pleasure', 'do', 'business', 'look', 'forward', 'order', 'item', 'thank'
# Review number 1  seems to be Positive
#
# The clean review is :  'thrill', 'quality', 'fit', 't-shirt', 'nicely', 'package', 'definitely', 're-ordering', 'future', 'kristina', 'spain'
# Review number 2  seems to be Positive
#
# The clean review is :  'miss', 'refund', 'return', 'parcel', 'get', 'date', 'would', 'get', 'refund', 'five', 'day', 'date', 'refund', 'contact', 'customer', 'support', 'advise', 'wait', 'another', '14', 'day', 'service', 'unhelpful', 'rude', 'time'
# Review number 3  seems to be Negative
